# %% [markdown]
# # Lecture 3: Introduction to Pandas
#
# This notebook introduces the basics of pandas, a powerful data manipulation and analysis library for Python.

# %%
# First, let's load the data (if not already loaded)
import pandas as pd
url = "https://zenodo.org/records/17098555/files/combined_model_crispr_data_filtered.csv?download=1"
df = pd.read_csv(url)

# %%
import pandas as pd

# %% [markdown]
# ## Loading Data from Zenodo
#
# We'll load a CRISPR dataset from Zenodo to explore pandas functionality.

# %%
url = "https://zenodo.org/records/17098555/files/combined_model_crispr_data_filtered.csv?download=1"
df = pd.read_csv(url)

# %% [markdown]
# ## Basic DataFrame Inspection
#
# Let's explore the basic commands to inspect our DataFrame.

# %% [markdown]
# ### 1. Check DataFrame dimensions with `.shape`
#
# The `.shape` attribute returns a tuple showing (rows, columns). This gives you a quick overview of your dataset size.

# %%
df.shape
# Out:
# (94, 17211)

# %% [markdown]
# ### 2. Preview the first few rows with `.head()`
#
# The `.head()` method shows the first 5 rows by default. This helps you understand the structure and content of your data quickly. You can specify a different number of rows with `.head(n)`.

# %%
df.head()
# Out:
#      model_id cell_line_name stripped_cell_line_name oncotree_lineage  \
# 0  ACH-000004            HEL                     HEL          Myeloid
# 1  ACH-000005     HEL 92.1.7                 HEL9217          Myeloid
# 2  ACH-000017        SK-BR-3                   SKBR3           Breast
# 3  ACH-000019           MCF7                    MCF7           Breast
# 4  ACH-000028          KPL-1                    KPL1           Breast
#
#     oncotree_primary_disease           oncotree_subtype      A1BG      A1CF  \
# 0     Acute Myeloid Leukemia                   AML, NOS  0.005506 -0.069734
# 1     Acute Myeloid Leukemia     Acute Myeloid Leukemia -0.112103  0.008739
# 2  Invasive Breast Carcinoma  Invasive Breast Carcinoma -0.032172 -0.102181
# 3  Invasive Breast Carcinoma  Invasive Breast Carcinoma  0.036307  0.018542
# 4  Invasive Breast Carcinoma  Invasive Breast Carcinoma -0.187719 -0.149819
#
#         A2M     A2ML1  ...    ZWILCH     ZWINT      ZXDA      ZXDB      ZXDC  \
# 0 -0.098829 -0.018614  ... -0.178914 -0.331030  0.233527  0.079958  0.084987
# 1  0.157658  0.106528  ... -0.273276 -0.341893 -0.027406 -0.080102 -0.027048
# 2 -0.012779  0.018938  ... -0.257300 -0.425172  0.048183  0.278794 -0.110023
# 3  0.095517  0.052744  ... -0.131793 -0.744819  0.067860  0.021533  0.030147
# 4  0.077679  0.123123  ... -0.493698 -0.536292  0.143591  0.076073 -0.034894
#
#      ZYG11A    ZYG11B       ZYX     ZZEF1      ZZZ3
# 0  0.059995 -0.313832  0.111395  0.261894 -0.086860
# 1 -0.247472 -0.132481 -0.061705  0.039933 -0.191611
# 2 -0.030859 -0.207186  0.053118 -0.257893 -0.201468
# 3 -0.038263 -0.150743  0.185094 -0.108240 -0.490506
# 4 -0.003931 -0.071018 -0.119227 -0.118681 -0.194408
#
# [5 rows x 17211 columns]

# %% [markdown]
# ### 3. Get detailed information with `.info()`
#
# The `.info()` method provides a comprehensive overview including:
# - Number of rows and columns
# - Column names and their data types
# - Non-null count for each column (useful for identifying missing data)
# - Memory usage of the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Columns: 17211 entries, model_id to ZZZ3
# dtypes: float64(17205), object(6)
# memory usage: 12.3+ MB

# %% [markdown]
# ### 4. Statistical summary with `.describe()`
#
# The `.describe()` method generates descriptive statistics for numerical columns:
# - **count**: Number of non-null values
# - **mean**: Average value
# - **std**: Standard deviation (measure of spread)
# - **min/max**: Minimum and maximum values
# - **25%, 50%, 75%**: Quartiles (percentiles) that help understand data distribution

# %%
df.describe()
# Out:
#             A1BG       A1CF        A2M      A2ML1    A3GALT2     A4GALT  \
# count  94.000000  94.000000  94.000000  94.000000  94.000000  94.000000
# mean   -0.054935  -0.093692   0.029812   0.064967  -0.114661  -0.038680
# std     0.141256   0.106651   0.099385   0.095671   0.138206   0.099466
# min    -0.626283  -0.451665  -0.186092  -0.245270  -0.616101  -0.320568
# 25%    -0.112972  -0.138388  -0.026509   0.008149  -0.189462  -0.077790
# 50%    -0.070896  -0.091606   0.028296   0.060233  -0.084616  -0.053613
# 75%     0.004349  -0.030879   0.081367   0.117312  -0.025943   0.013791
# max     0.464101   0.210794   0.411906   0.313749   0.168673   0.236373
#
#            A4GNT       AAAS       AACS      AADAC  ...     ZWILCH      ZWINT  \
# count  94.000000  94.000000  94.000000  94.000000  ...  94.000000  94.000000
# mean    0.032787  -0.115873  -0.045571   0.108615  ...  -0.204066  -0.379184
# std     0.102891   0.219413   0.114337   0.090607  ...   0.171297   0.236019
# min    -0.162090  -0.831448  -0.296332  -0.164341  ...  -0.872698  -0.893691
# 25%    -0.036059  -0.239771  -0.110043   0.051166  ...  -0.272001  -0.514609
# 50%     0.018043  -0.096770  -0.056092   0.121614  ...  -0.208706  -0.377878
# 75%     0.090748   0.014472   0.009893   0.163191  ...  -0.092252  -0.225159
# max     0.382592   0.330231   0.334593   0.357325  ...   0.163556   0.193544
#
#             ZXDA       ZXDB       ZXDC     ZYG11A     ZYG11B        ZYX  \
# count  94.000000  94.000000  94.000000  94.000000  94.000000  94.000000
# mean    0.047896   0.082465  -0.071971  -0.040266  -0.127970  -0.020021
# std     0.152510   0.142629   0.124164   0.094981   0.132863   0.140636
# min    -0.650110  -0.323497  -0.489390  -0.247472  -0.446544  -0.456646
# 25%    -0.035083   0.012940  -0.150538  -0.094475  -0.201977  -0.098958
# 50%     0.065820   0.082953  -0.080664  -0.039286  -0.132295  -0.019451
# 75%     0.139735   0.163576  -0.016515   0.006408  -0.051638   0.054303
# max     0.398083   0.462117   0.395878   0.216754   0.365249   0.285742
#
#            ZZEF1       ZZZ3
# count  94.000000  94.000000
# mean   -0.118972  -0.307278
# std     0.145147   0.190793
# min    -0.589946  -1.146622
# 25%    -0.201573  -0.383100
# 50%    -0.119042  -0.296210
# 75%    -0.038290  -0.201779
# max     0.305158   0.136894
#
# [8 rows x 17205 columns]

# %% [markdown]
# ### 5. List all column names with `.columns`
#
# The `.columns` attribute returns an Index object containing all column names. This is essential for understanding what variables are available in your dataset and for referencing specific columns later.

# %%
df.columns
# Out:
# Index(['model_id', 'cell_line_name', 'stripped_cell_line_name',
#        'oncotree_lineage', 'oncotree_primary_disease', 'oncotree_subtype',
#        'A1BG', 'A1CF', 'A2M', 'A2ML1',
#        ...
#        'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B', 'ZYX',
#        'ZZEF1', 'ZZZ3'],
#       dtype='object', length=17211)

# %%
df.loc[df["cell_line_name"] == "MCF7", "A1BG"].values[0].round(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.loc[df["cell_line_name"] == "MCF7", "A1BG"].values[0].round(2).dtype()
#
# TypeError: 'numpy.dtypes.Float64DType' object is not callable
